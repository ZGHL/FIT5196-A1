# %% [markdown]
# # FIT5196 Assessment 1 — Group030 EDA
# The assessed PDF is `Group030_EDA.pdf`; this notebook recreates all tables, statistics and figures from the six submitted CSVs.

# %% [markdown]
# ## 0. Configuration and data loading

# %%
from pathlib import Path
GROUP_ID="Group030"
OUTPUT_DIR=Path("outputs")
from Group030_EDA import load_tables, make_eda
tables=load_tables()
{name:len(df) for name,df in tables.items()}

# %% [markdown]
# ## 1. Context and data-preparation assurance
# Structured parsing, data-driven overlap reconciliation, published monetary arithmetic and separate multilingual/Latin text outputs are documented by MAP-* IDs. Schema, key, overlap, arithmetic, temporal and text checks pass under VAL-SCHEMA-*, VAL-PK/FK-*, VAL-FLOW-*, VAL-ARITH-*, VAL-TIME-* and VAL-TEXT-*.

# %% [markdown]
# ## 2. Assessed visualisations
# Figures 1–7 cover distribution, bivariate comparison, segmentation, time, review behaviour, delivery operations and product/category performance. `make_eda` states metrics at their correct grain and asserts three many-to-one joins do not multiply the left table.

# %%
figures, metrics=make_eda()
metrics

# %% [markdown]
# ### Figure catalogue and analytical contracts
# 1. Order-total distribution — unit/denominator: each of 5,000 orders; orders table; limitation: revenue is not margin.
# 2. Channel mean — unit: order; denominator: all orders per channel; orders table; limitation: composition confounding.
# 3. Loyalty × channel — unit: order; orders.customer_id → customers.customer_id; limitation: repeated customers.
# 4. Monthly volume — unit: order-month; orders table; limitation: one year only.
# 5. Rating/length/helpfulness — unit: review; product_reviews table; limitation: exposure unobserved.
# 6. Rating × service/OTIF — unit: review; reviews.order_id → deliveries.order_id; limitation: selection and confounding.
# 7. Category revenue — unit: order item; items.product_id → products.product_id; limitation: revenue is not profit.

# %% [markdown]
# ## 3. Ten evidence-based findings
# The PDF contains exactly ten numbered findings, each citing a figure and reporting grain, magnitude/denominator, uncertainty and proportionate implication.

# %% [markdown]
# ## 4. Five ML questions
# The PDF specifies exactly five questions spanning classification, regression, forecasting and clustering, with unit, target/objective, decision-time predictors, validation, metrics and leakage/fairness/deployment risks.

# %% [markdown]
# ## 5. Limitations and conclusion
# One retailer-year limits external and seasonal inference; observations are non-independent and observational; review selection, product exposure, day-level delivery precision and small language groups constrain interpretation. No causal claim is made.
